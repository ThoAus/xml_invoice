# %%
from asn1crypto import cms

def extract_p7m(p7m_path, output_path):
    with open(p7m_path, 'rb') as f:
        p7m_data = f.read()

    # Load the CMS (Cryptographic Message Syntax) structure
    content_info = cms.ContentInfo.load(p7m_data)

    # Drill down: ContentInfo -> SignedData -> EncapsulatedContentInfo -> Content
    # The actual XML is inside the 'content' field of 'encap_content_info'
    signed_data = content_info['content']
    xml_content = signed_data['encap_content_info']['content'].native

    with open(output_path, 'wb') as f:
        f.write(xml_content)
    
    print(f"Extracted to {output_path}")

# Usage
extract_p7m(
    p7m_path='p7m_files/FatturaPa  GSPA-2023-26-28.02.23 BAUSTOFF H & S  SAS DI GUFLER JOHANN & CO.  IT02046570426_3XJiD(E100798828).P7M',
    output_path='xml_files/invoice.xml')
# Out:
# Extracted to xml_files/invoice.xml

# %%
# find .p7m files in p7m_files/ and extract them to xml_files/
import os

for filename in os.listdir('p7m_files'):
    if filename.endswith('.P7M') or filename.endswith('.p7m'):
        p7m_path = os.path.join('p7m_files', filename)
        xml_filename = filename[:-4] + '.xml'
        output_path = os.path.join('xml_files', xml_filename)
        extract_p7m(p7m_path, output_path)
# Out:
# Extracted to xml_files\FatturaPa  GSPA-2023-26-28.02.23 BAUSTOFF H & S  SAS DI GUFLER JOHANN & CO.  IT02046570426_3XJiD(E100798828).xml
# Extracted to xml_files\FatturaPa  GSPA-2023-28-15.03.23 BAUSTOFF H & S  SAS DI GUFLER JOHANN & CO.  IT02046570426_41Rik(E100801151).xml
# Extracted to xml_files\FatturaPa  GSPA-2023-29-15.03.23 BAUSTOFF H & S  SAS DI GUFLER JOHANN & CO.  IT02046570426_41Riv(E100801154).xml
# Extracted to xml_files\FatturaPa  GSPA-2023-30-15.03.23 BAUSTOFF H & S  SAS DI GUFLER JOHANN & CO.  IT02046570426_41RiC(E100801158).xml
# Extracted to xml_files\FatturaPa  GSPA-2023-56-30.04.23 BAUSTOFF H & S  SAS DI GUFLER JOHANN & CO.  IT02046570426_4tjkA(E100817650).xml
# Extracted to xml_files\FatturaPa  GSPA-2024-37-30.04.24 BAUSTOFF H & S  SAS DI GUFLER JOHANN & CO.  IT02046570426_80iDL(E101036927).xml
# Extracted to xml_files\FatturaPa  RGPA-2023-102-31.08.23 BAUSTOFF H & S  SAS DI GUFLER JOHANN & CO.  IT02046570426_5Cu1C(E100861902).xml
# Extracted to xml_files\FatturaPa  RGPA-2023-103-31.08.23 BAUSTOFF H & S  SAS DI GUFLER JOHANN & CO.  IT02046570426_5Cu1P(E100861905).xml
# Extracted to xml_files\FatturaPa  RGPA-2023-104-31.08.23 BAUSTOFF H & S  SAS DI GUFLER JOHANN & CO.  IT02046570426_5Cu23(E100861909).xml
# Extracted to xml_files\FatturaPa  RGPA-2023-105-31.08.23 BAUSTOFF H & S  SAS DI GUFLER JOHANN & CO.  IT02046570426_5Cu2j(E100861912).xml
# Extracted to xml_files\FatturaPa  RGPA-2023-112-29.09.23 BAUSTOFF H & S  SAS DI GUFLER JOHANN & CO.  IT02046570426_5TrhZ(E100872428).xml
# Extracted to xml_files\FatturaPa  RGPA-2023-113-29.09.23 BAUSTOFF H & S  SAS DI GUFLER JOHANN & CO.  IT02046570426_5Trij(E100872413).xml
# Extracted to xml_files\FatturaPa  RGPA-2023-114-29.09.23 BAUSTOFF H & S  SAS DI GUFLER JOHANN & CO.  IT02046570426_5TriI(E100872432).xml
# Extracted to xml_files\FatturaPa  RGPA-2023-123-31.10.23 BAUSTOFF H & S  SAS DI GUFLER JOHANN & CO.  IT02046570426_6eGhV(E100882913).xml
# Extracted to xml_files\FatturaPa  RGPA-2023-124-31.10.23 BAUSTOFF H & S  SAS DI GUFLER JOHANN & CO.  IT02046570426_6eGif(E100882979).xml
# Extracted to xml_files\FatturaPa  RGPA-2023-125-31.10.23 BAUSTOFF H & S  SAS DI GUFLER JOHANN & CO.  IT02046570426_6eGiz(E100882983).xml
# Extracted to xml_files\FatturaPa  RGPA-2023-134-27.11.23 BAUSTOFF H & S  SAS DI GUFLER JOHANN & CO.  IT02046570426_6ur9Q(E100894107).xml
# Extracted to xml_files\FatturaPa  RGPA-2023-138-30.11.23 BAUSTOFF H & S  SAS DI GUFLER JOHANN & CO.  IT02046570426_6xbHe(E100894404).xml
# Extracted to xml_files\FatturaPa  RGPA-2023-139-30.11.23 BAUSTOFF H & S  SAS DI GUFLER JOHANN & CO.  IT02046570426_6xbHA(E100894407).xml
# Extracted to xml_files\FatturaPa  RGPA-2023-140-30.11.23 BAUSTOFF H & S  SAS DI GUFLER JOHANN & CO.  IT02046570426_6xbHU(E100894411).xml
# Extracted to xml_files\FatturaPa  RGPA-2023-19-28.02.23 BAUSTOFF H & S  SAS DI GUFLER JOHANN & CO.  IT02046570426_3Ro0W(E100795754).xml
# Extracted to xml_files\FatturaPa  RGPA-2023-20-28.02.23 BAUSTOFF H & S  SAS DI GUFLER JOHANN & CO.  IT02046570426_3Ro1o(E100795757).xml
# Extracted to xml_files\FatturaPa  RGPA-2023-21-28.02.23 BAUSTOFF H & S  SAS DI GUFLER JOHANN & CO.  IT02046570426_3Ro1H(E100798819).xml
# Extracted to xml_files\FatturaPa  RGPA-2023-22-28.02.23 BAUSTOFF H & S  SAS DI GUFLER JOHANN & CO.  IT02046570426_3Ro2a(E100795762).xml
# Extracted to xml_files\FatturaPa  RGPA-2023-23-28.02.23 BAUSTOFF H & S  SAS DI GUFLER JOHANN & CO.  IT02046570426_3Ro2N(E100795773).xml
# Extracted to xml_files\FatturaPa  RGPA-2023-24-28.02.23 BAUSTOFF H & S  SAS DI GUFLER JOHANN & CO.  IT02046570426_3Ro33(E100798822).xml
# Extracted to xml_files\FatturaPa  RGPA-2023-25-28.02.23 BAUSTOFF H & S  SAS DI GUFLER JOHANN & CO.  IT02046570426_3XJiw(E100798825).xml
# Extracted to xml_files\FatturaPa  RGPA-2023-27-28.02.23 BAUSTOFF H & S  SAS DI GUFLER JOHANN & CO.  IT02046570426_3XJiR(E100798831).xml
# Extracted to xml_files\FatturaPa  RGPA-2023-31-15.03.23 BAUSTOFF H & S  SAS DI GUFLER JOHANN & CO.  IT02046570426_41RiM(E100801175).xml
# Extracted to xml_files\FatturaPa  RGPA-2023-32-15.03.23 BAUSTOFF H & S  SAS DI GUFLER JOHANN & CO.  IT02046570426_41RiW(E100801180).xml
# Extracted to xml_files\FatturaPa  RGPA-2023-33-15.03.23 BAUSTOFF H & S  SAS DI GUFLER JOHANN & CO.  IT02046570426_41Rj6(E100801183).xml
# Extracted to xml_files\FatturaPa  RGPA-2023-39-31.03.23 BAUSTOFF H & S  SAS DI GUFLER JOHANN & CO.  IT02046570426_4aZX0(E100808153).xml
# Extracted to xml_files\FatturaPa  RGPA-2023-40-31.03.23 BAUSTOFF H & S  SAS DI GUFLER JOHANN & CO.  IT02046570426_4aZXj(E100808173).xml
# Extracted to xml_files\FatturaPa  RGPA-2023-41-31.03.23 BAUSTOFF H & S  SAS DI GUFLER JOHANN & CO.  IT02046570426_4aZXA(E100808222).xml
# Extracted to xml_files\FatturaPa  RGPA-2023-42-31.03.23 BAUSTOFF H & S  SAS DI GUFLER JOHANN & CO.  IT02046570426_4aZXZ(E100808229).xml
# Extracted to xml_files\FatturaPa  RGPA-2023-43-31.03.23 BAUSTOFF H & S  SAS DI GUFLER JOHANN & CO.  IT02046570426_4aZYe(E100808245).xml
# Extracted to xml_files\FatturaPa  RGPA-2023-44-31.03.23 BAUSTOFF H & S  SAS DI GUFLER JOHANN & CO.  IT02046570426_4aZYy(E100808157).xml
# Extracted to xml_files\FatturaPa  RGPA-2023-45-31.03.23 BAUSTOFF H & S  SAS DI GUFLER JOHANN & CO.  IT02046570426_4aZYP(E100808248).xml
# Extracted to xml_files\FatturaPa  RGPA-2023-52-30.04.23 BAUSTOFF H & S  SAS DI GUFLER JOHANN & CO.  IT02046570426_4sUwY(E100817239).xml
# Extracted to xml_files\FatturaPa  RGPA-2023-53-30.04.23 BAUSTOFF H & S  SAS DI GUFLER JOHANN & CO.  IT02046570426_4sUx0(E100817242).xml
# Extracted to xml_files\FatturaPa  RGPA-2023-66-31.05.23 BAUSTOFF H & S  SAS DI GUFLER JOHANN & CO.  IT02046570426_4L5tn(E100829112).xml
# Extracted to xml_files\FatturaPa  RGPA-2023-67-31.05.23 BAUSTOFF H & S  SAS DI GUFLER JOHANN & CO.  IT02046570426_4L5tD(E100829257).xml
# Extracted to xml_files\FatturaPa  RGPA-2023-79-30.06.23 BAUSTOFF H & S  SAS DI GUFLER JOHANN & CO.  IT02046570426_53rlf(E100842328).xml
# Extracted to xml_files\FatturaPa  RGPA-2023-80-30.06.23 BAUSTOFF H & S  SAS DI GUFLER JOHANN & CO.  IT02046570426_53rlt(E100842334).xml
# Extracted to xml_files\FatturaPa  RGPA-2023-90-31.07.23 BAUSTOFF H & S  SAS DI GUFLER JOHANN & CO.  IT02046570426_5nskb(E100851263).xml
# Extracted to xml_files\FatturaPa  RGPA-2024-10-29.02.24 BAUSTOFF H & S  SAS DI GUFLER JOHANN & CO.  IT02046570426_7peww(E101007592).xml
# Extracted to xml_files\FatturaPa  RGPA-2024-101-30.09.24 BAUSTOFF H & S  SAS DI GUFLER JOHANN & CO.  IT02046570426_9pPrF(E101097454).xml
# Extracted to xml_files\FatturaPa  RGPA-2024-102-30.09.24 BAUSTOFF H & S  SAS DI GUFLER JOHANN & CO.  IT02046570426_9pPsg(E101097456).xml
# Extracted to xml_files\FatturaPa  RGPA-2024-103-30.09.24 BAUSTOFF H & S  SAS DI GUFLER JOHANN & CO.  IT02046570426_9pPsH(E101097458).xml
# Extracted to xml_files\FatturaPa  RGPA-2024-104-30.09.24 BAUSTOFF H & S  SAS DI GUFLER JOHANN & CO.  IT02046570426_9pPt3(E101097460).xml
# Extracted to xml_files\FatturaPa  RGPA-2024-105-30.09.24 BAUSTOFF H & S  SAS DI GUFLER JOHANN & CO.  IT02046570426_9pPtr(E101097462).xml
# Extracted to xml_files\FatturaPa  RGPA-2024-116-31.10.24 BAUSTOFF H & S  SAS DI GUFLER JOHANN & CO.  IT02046570426_9JHpV(E101121465).xml
# Extracted to xml_files\FatturaPa  RGPA-2024-117-31.10.24 BAUSTOFF H & S  SAS DI GUFLER JOHANN & CO.  IT02046570426_9JHqB(E101121467).xml
# Extracted to xml_files\FatturaPa  RGPA-2024-129-30.11.24 BAUSTOFF H & S  SAS DI GUFLER JOHANN & CO.  IT02046570426_a30Ov(E101194652).xml
# Extracted to xml_files\FatturaPa  RGPA-2024-130-30.11.24 BAUSTOFF H & S  SAS DI GUFLER JOHANN & CO.  IT02046570426_a30OY(E101194673).xml
# Extracted to xml_files\FatturaPa  RGPA-2024-131-30.11.24 BAUSTOFF H & S  SAS DI GUFLER JOHANN & CO.  IT02046570426_a30Po(E101194677).xml
# Extracted to xml_files\FatturaPa  RGPA-2024-137-20.12.24 BAUSTOFF H & S  SAS DI GUFLER JOHANN & CO.  IT02046570426_agSZ7(E101201888).xml
# Extracted to xml_files\FatturaPa  RGPA-2024-138-20.12.24 BAUSTOFF H & S  SAS DI GUFLER JOHANN & CO.  IT02046570426_agSZs(E101201891).xml
# Extracted to xml_files\FatturaPa  RGPA-2024-16-29.03.24 BAUSTOFF H & S  SAS DI GUFLER JOHANN & CO.  IT02046570426_7Gs56(E101026778).xml
# Extracted to xml_files\FatturaPa  RGPA-2024-17-29.03.24 BAUSTOFF H & S  SAS DI GUFLER JOHANN & CO.  IT02046570426_7Gs5A(E101026781).xml
# Extracted to xml_files\FatturaPa  RGPA-2024-18-29.03.24 BAUSTOFF H & S  SAS DI GUFLER JOHANN & CO.  IT02046570426_7Gs5V(E101026784).xml
# Extracted to xml_files\FatturaPa  RGPA-2024-19-29.03.24 BAUSTOFF H & S  SAS DI GUFLER JOHANN & CO.  IT02046570426_7Gs6D(E101026787).xml
# Extracted to xml_files\FatturaPa  RGPA-2024-20-29.03.24 BAUSTOFF H & S  SAS DI GUFLER JOHANN & CO.  IT02046570426_7Gs73(E101026791).xml
# Extracted to xml_files\FatturaPa  RGPA-2024-3-31.01.24 BAUSTOFF H & S  SAS DI GUFLER JOHANN & CO.  IT02046570426_76Lk5(E100913932).xml
# Extracted to xml_files\FatturaPa  RGPA-2024-33-30.04.24 BAUSTOFF H & S  SAS DI GUFLER JOHANN & CO.  IT02046570426_7ZRHS(E101036678).xml
# Extracted to xml_files\FatturaPa  RGPA-2024-34-30.04.24 BAUSTOFF H & S  SAS DI GUFLER JOHANN & CO.  IT02046570426_7ZRIf(E101036681).xml
# Extracted to xml_files\FatturaPa  RGPA-2024-35-30.04.24 BAUSTOFF H & S  SAS DI GUFLER JOHANN & CO.  IT02046570426_7ZRIO(E101036684).xml
# Extracted to xml_files\FatturaPa  RGPA-2024-36-30.04.24 BAUSTOFF H & S  SAS DI GUFLER JOHANN & CO.  IT02046570426_7ZRJ9(E101036688).xml
# Extracted to xml_files\FatturaPa  RGPA-2024-4-31.01.24 BAUSTOFF H & S  SAS DI GUFLER JOHANN & CO.  IT02046570426_76Lkh(E100913935).xml
# Extracted to xml_files\FatturaPa  RGPA-2024-50-31.05.24 BAUSTOFF H & S  SAS DI GUFLER JOHANN & CO.  IT02046570426_8i3sA(E101047268).xml
# Extracted to xml_files\FatturaPa  RGPA-2024-51-31.05.24 BAUSTOFF H & S  SAS DI GUFLER JOHANN & CO.  IT02046570426_8i3sQ(E101047272).xml
# Extracted to xml_files\FatturaPa  RGPA-2024-52-31.05.24 BAUSTOFF H & S  SAS DI GUFLER JOHANN & CO.  IT02046570426_8i3t9(E101047275).xml
# Extracted to xml_files\FatturaPa  RGPA-2024-53-31.05.24 BAUSTOFF H & S  SAS DI GUFLER JOHANN & CO.  IT02046570426_8i3tv(E101047278).xml
# Extracted to xml_files\FatturaPa  RGPA-2024-54-31.05.24 BAUSTOFF H & S  SAS DI GUFLER JOHANN & CO.  IT02046570426_8i3tM(E101047281).xml
# Extracted to xml_files\FatturaPa  RGPA-2024-60-30.06.24 BAUSTOFF H & S  SAS DI GUFLER JOHANN & CO.  IT02046570426_8AC7m(E101058934).xml
# Extracted to xml_files\FatturaPa  RGPA-2024-61-30.06.24 BAUSTOFF H & S  SAS DI GUFLER JOHANN & CO.  IT02046570426_8AC7Z(E101058937).xml
# Extracted to xml_files\FatturaPa  RGPA-2024-62-30.06.24 BAUSTOFF H & S  SAS DI GUFLER JOHANN & CO.  IT02046570426_8AC8q(E101058940).xml
# Extracted to xml_files\FatturaPa  RGPA-2024-73-31.07.24 BAUSTOFF H & S  SAS DI GUFLER JOHANN & CO.  IT02046570426_8UxCA(E101077926).xml
# Extracted to xml_files\FatturaPa  RGPA-2024-74-31.07.24 BAUSTOFF H & S  SAS DI GUFLER JOHANN & CO.  IT02046570426_8UxD2(E101077929).xml
# Extracted to xml_files\FatturaPa  RGPA-2024-75-31.07.24 BAUSTOFF H & S  SAS DI GUFLER JOHANN & CO.  IT02046570426_8UxDr(E101077934).xml
# Extracted to xml_files\FatturaPa  RGPA-2024-76-31.07.24 BAUSTOFF H & S  SAS DI GUFLER JOHANN & CO.  IT02046570426_8UxDR(E101077976).xml
# Extracted to xml_files\FatturaPa  RGPA-2024-77-31.07.24 BAUSTOFF H & S  SAS DI GUFLER JOHANN & CO.  IT02046570426_8UxEc(E101077986).xml
# Extracted to xml_files\FatturaPa  RGPA-2024-86-30.08.24 BAUSTOFF H & S  SAS DI GUFLER JOHANN & CO.  IT02046570426_98zVp(E101087502).xml
# Extracted to xml_files\FatturaPa  RGPA-2024-87-30.08.24 BAUSTOFF H & S  SAS DI GUFLER JOHANN & CO.  IT02046570426_98zVT(E101087504).xml
# Extracted to xml_files\FatturaPa  RGPA-2024-88-30.08.24 BAUSTOFF H & S  SAS DI GUFLER JOHANN & CO.  IT02046570426_98zWc(E101087506).xml
# Extracted to xml_files\FatturaPa  RGPA-2024-89-30.08.24 BAUSTOFF H & S  SAS DI GUFLER JOHANN & CO.  IT02046570426_98zWt(E101087509).xml
# Extracted to xml_files\FatturaPa  RGPA-2024-9-29.02.24 BAUSTOFF H & S  SAS DI GUFLER JOHANN & CO.  IT02046570426_7pewb(E101007586).xml
# Extracted to xml_files\FatturaPa  RGPA-2024-90-30.08.24 BAUSTOFF H & S  SAS DI GUFLER JOHANN & CO.  IT02046570426_98zWK(E101087511).xml
# Extracted to xml_files\FatturaPa  RGPA-2025-100-31.10.25 BAUSTOFF H & S  SAS DI GUFLER JOHANN & CO.  IT02046570426_dcFAo(E101349546).xml
# Extracted to xml_files\FatturaPa  RGPA-2025-101-31.10.25 BAUSTOFF H & S  SAS DI GUFLER JOHANN & CO.  IT02046570426_dcFAM(E101347349).xml
# Extracted to xml_files\FatturaPa  RGPA-2025-102-31.10.25 BAUSTOFF H & S  SAS DI GUFLER JOHANN & CO.  IT02046570426_dcFBg(E101347352).xml
# Extracted to xml_files\FatturaPa  RGPA-2025-103-31.10.25 BAUSTOFF H & S  SAS DI GUFLER JOHANN & CO.  IT02046570426_dcFBN(E101347355).xml
# Extracted to xml_files\FatturaPa  RGPA-2025-104-31.10.25 BAUSTOFF H & S  SAS DI GUFLER JOHANN & CO.  IT02046570426_dcFC9(E101347358).xml
# Extracted to xml_files\FatturaPa  RGPA-2025-116-30.11.25 BAUSTOFF H & S  SAS DI GUFLER JOHANN & CO.  IT02046570426_dvR68(E101357492).xml
# Extracted to xml_files\FatturaPa  RGPA-2025-117-30.11.25 BAUSTOFF H & S  SAS DI GUFLER JOHANN & CO.  IT02046570426_dvR6G(E101357680).xml
# Extracted to xml_files\FatturaPa  RGPA-2025-118-30.11.25 BAUSTOFF H & S  SAS DI GUFLER JOHANN & CO.  IT02046570426_dvR7a(E101357683).xml
# Extracted to xml_files\FatturaPa  RGPA-2025-119-30.11.25 BAUSTOFF H & S  SAS DI GUFLER JOHANN & CO.  IT02046570426_dvR7S(E101357686).xml
# Extracted to xml_files\FatturaPa  RGPA-2025-12-28.02.25 BAUSTOFF H & S  SAS DI GUFLER JOHANN & CO.  IT02046570426_aTMty(E101244256).xml
# Extracted to xml_files\FatturaPa  RGPA-2025-20-31.03.25 BAUSTOFF H & S  SAS DI GUFLER JOHANN & CO.  IT02046570426_bbAou(E101263543).xml
# Extracted to xml_files\FatturaPa  RGPA-2025-21-31.03.25 BAUSTOFF H & S  SAS DI GUFLER JOHANN & CO.  IT02046570426_bbAp9(E101263546).xml
# Extracted to xml_files\FatturaPa  RGPA-2025-22-31.03.25 BAUSTOFF H & S  SAS DI GUFLER JOHANN & CO.  IT02046570426_bbApC(E101263559).xml
# Extracted to xml_files\FatturaPa  RGPA-2025-33-30.04.25 BAUSTOFF H & S  SAS DI GUFLER JOHANN & CO.  IT02046570426_btLUc(E101275389).xml
# Extracted to xml_files\FatturaPa  RGPA-2025-34-30.04.25 BAUSTOFF H & S  SAS DI GUFLER JOHANN & CO.  IT02046570426_btLUv(E101275393).xml
# Extracted to xml_files\FatturaPa  RGPA-2025-4-31.01.25 BAUSTOFF H & S  SAS DI GUFLER JOHANN & CO.  IT02046570426_aDmS5(E101215253).xml
# Extracted to xml_files\FatturaPa  RGPA-2025-42-31.05.25 BAUSTOFF H & S  SAS DI GUFLER JOHANN & CO.  IT02046570426_bMXTX(E101286810).xml
# Extracted to xml_files\FatturaPa  RGPA-2025-43-31.05.25 BAUSTOFF H & S  SAS DI GUFLER JOHANN & CO.  IT02046570426_bMXUl(E101286813).xml
# Extracted to xml_files\FatturaPa  RGPA-2025-44-31.05.25 BAUSTOFF H & S  SAS DI GUFLER JOHANN & CO.  IT02046570426_bMXUE(E101286861).xml
# Extracted to xml_files\FatturaPa  RGPA-2025-5-31.01.25 BAUSTOFF H & S  SAS DI GUFLER JOHANN & CO.  IT02046570426_aDmSi(E101215267).xml
# Extracted to xml_files\FatturaPa  RGPA-2025-54-30.06.25 BAUSTOFF H & S  SAS DI GUFLER JOHANN & CO.  IT02046570426_c3STJ(E101297752).xml
# Extracted to xml_files\FatturaPa  RGPA-2025-64-31.07.25 BAUSTOFF H & S  SAS DI GUFLER JOHANN & CO.  IT02046570426_coC6X(E101312354).xml
# Extracted to xml_files\FatturaPa  RGPA-2025-65-31.07.25 BAUSTOFF H & S  SAS DI GUFLER JOHANN & CO.  IT02046570426_coC78(E101312358).xml
# Extracted to xml_files\FatturaPa  RGPA-2025-66-31.07.25 BAUSTOFF H & S  SAS DI GUFLER JOHANN & CO.  IT02046570426_coC7g(E101312362).xml
# Extracted to xml_files\FatturaPa  RGPA-2025-74-29.08.25 BAUSTOFF H & S  SAS DI GUFLER JOHANN & CO.  IT02046570426_cC1gl(E101323476).xml
# Extracted to xml_files\FatturaPa  RGPA-2025-75-29.08.25 BAUSTOFF H & S  SAS DI GUFLER JOHANN & CO.  IT02046570426_cC1gz(E101323480).xml
# Extracted to xml_files\FatturaPa  RGPA-2025-76-29.08.25 BAUSTOFF H & S  SAS DI GUFLER JOHANN & CO.  IT02046570426_cC1gK(E101323483).xml
# Extracted to xml_files\FatturaPa  RGPA-2025-77-29.08.25 BAUSTOFF H & S  SAS DI GUFLER JOHANN & CO.  IT02046570426_cC1gT(E101323486).xml
# Extracted to xml_files\FatturaPa  RGPA-2025-90-30.09.25 BAUSTOFF H & S  SAS DI GUFLER JOHANN & CO.  IT02046570426_cU976(E101335933).xml
# Extracted to xml_files\FatturaPa  RGPA-2025-91-30.09.25 BAUSTOFF H & S  SAS DI GUFLER JOHANN & CO.  IT02046570426_cU97v(E101335936).xml
